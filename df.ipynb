# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression   #gradient assent
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error

# %%
d={"study_hour":list(range(1,11)),"score":list(range(50,96,5))}
df=pd.DataFrame(d)
df.head()
# Out:
#    study_hour  score
# 0           1     50
# 1           2     55
# 2           3     60
# 3           4     65
# 4           5     70

# %%
x=df[['study_hour']]
y=df[['score']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
model=LinearRegression()

# %%
#Train the model

model.fit(x_train,y_train)  #internally it runs y=mx+c and give one equation
# Out:
# LinearRegression()

# %%
model.score(x_train,y_train)*100,model.score(x_test,y_test)*100   #for accuracy check
# Out:
# (100.0, 100.0)

# %%
model.intercept_
# Out:
# array([45.])

# %%
model.coef_    #slope
# Out:
# array([[5.]])

# %%
ypred=model.predict(x_test)
ypred  #we use y_test because machine already now the train datas
# Out:
# array([[90.],
#        [55.]])

# %%
y_test=ypred

# %%
plt.figure(figsize=(4,3))
plt.scatter(x_test,y_test)
plt.scatter(x_test,ypred)
plt.show()

# %%
r2_score(y_test,ypred)
# Out:
# 1.0

# %%
model.score(x_test,y_test)
# Out:
# 1.0

# %%
mean_squared_error(y_test,ypred)    #to find average error dfference
# Out:
# 0.0

# %%
mean_absolute_error(y_test,ypred)
# Out:
# 0.0

# %% [markdown]
# Conclusion:
# 1) The initial value when x=0 is 45[intercept]
# 2) As study hour increses by 1hour he get 5 more marks
# 3) As output seen like the actual output and predicted output are same there is no error present
# 4) Accuracy of the model is 100%
# 5) MSE and MAE is zero
